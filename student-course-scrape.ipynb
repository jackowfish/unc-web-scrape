# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import pprint
from time import sleep

USER = 'deckerj'
PASS = 'ONLYALMONDFORPERI'

pp = pprint.PrettyPrinter(indent=4)

options = Options()
options.add_argument('--headless')
driver = webdriver.Chrome('./chromedriver', options=options)

driver.get('https://pa.cc.unc.edu/psp/paprd/EMPLOYEE/EMPL/h/?tab=NC_REDIRECT&amp;TargetPage=PortalHome')
sleep(1)

user_entry = driver.find_element_by_id('username')
pwd_entry = driver.find_element_by_id('password')
sign_in = driver.find_element_by_xpath('/html/body/div/div/div/div/form/div[3]/button')
# login
user_entry.send_keys(USER)
pwd_entry.send_keys(PASS)
sign_in.click()
sleep(1)
print('Successfully logged in!')
# Navigate to inner iFrame of student center
driver.get('https://cs.cc.unc.edu/psc/campus/EMPLOYEE/SA/c/SA_LEARNER_SERVICES.SSS_STUDENT_CENTER.GBL?PortalActualURL=https%3a%2f%2fcs.cc.unc.edu%2fpsc%2fcampus%2fEMPLOYEE%2fSA%2fc%2fSA_LEARNER_SERVICES.SSS_STUDENT_CENTER.GBL&amp;PortalContentURL=https%3a%2f%2fcs.cc.unc.edu%2fpsc%2fcampus%2fEMPLOYEE%2fSA%2fc%2fSA_LEARNER_SERVICES.SSS_STUDENT_CENTER.GBL&amp;PortalContentProvider=SA&amp;PortalCRefLabel=Student%20Center&amp;PortalRegistryName=EMPLOYEE&amp;PortalServletURI=https%3a%2f%2fpa.cc.unc.edu%2fpsp%2fpaprd%2f&amp;PortalURI=https%3a%2f%2fpa.cc.unc.edu%2fpsc%2fpaprd%2f&amp;PortalHostNode=EMPL&amp;NoCrumbs=yes')
sleep(1)
# Navigate to my academics
driver.find_element_by_xpath("//*[@id='DERIVED_SSS_SCR_SSS_LINK_ANCHOR4']").click()
sleep(1)
# navigate to course history
driver.find_element_by_xpath("//*[@id='DERIVED_SSSACA2_SSS_ACAD_HISTORY']").click()
sleep(1)
# get course information
course_table = driver.find_element_by_xpath("//*[@id='CRSE_HIST$scroll$0']/tbody/tr/td/table/tbody")
courses = course_table.find_elements_by_css_selector('tr')
header = True
print(f"{len(courses)} courses")
courses_list = []
count = 0
for course in courses:
    if header:
        header = False
        continue
    else:
        course_dict = {
            "course" : course.find_element_by_id(f"CRSE_NAME${count}").get_attribute('innerHTML'),
            "name" : course.find_element_by_id(f"CRSE_LINK${count}").get_attribute('innerHTML'),
            "term" : course.find_element_by_id(f"CRSE_TERM${count}").get_attribute('innerHTML'),
            "grade" : course.find_element_by_id(f"CRSE_GRADE${count}").get_attribute('innerHTML'),
            "credits" : course.find_element_by_id(f"CRSE_UNITS${count}").get_attribute('innerHTML'),
        }
        count += 1
        courses_list.append(course_dict)

pp.pprint(courses_list)
# Out:
# Successfully logged in!
# 42 courses
# [   {   'course': 'APPL 110',
#         'credits': '3.00',
#         'grade': 'A',
#         'name': 'INTRO TO DESIGN AND MAKING',
#         'term': '2019 Spring'},
#     {   'course': 'BUSI 102',
#         'credits': '1.50',
#         'grade': 'B',
#         'name': 'FINANCIAL ACCOUNTING',
#         'term': '2019 Fall'},
#     {   'course': 'COMP 110',
#         'credits': '3.00',
#         'grade': 'A-',
#         'name': 'INTRO PROGRAMMING',
#         'term': '2018 Fall'},
#     {   'course': 'COMP 283',
#         'credits': '3.00',
#         'grade': 'B+',
#         'name': 'DISCRETE STRUCTURES',
#         'term': '2019 Fall'},
#     {   'course': 'COMP 290',
#         'credits': '1.00',
#         'grade': 'A',
#         'name': 'SPECIAL TOPICS IN COMPUTER SCI',
#         'term': '2020 Spring'},
#     {   'course': 'COMP 401',
#         'credits': '4.00',
#         'grade': 'B+',
#         'name': "FOUND'N OF PROGRAMG",
#         'term': '2019 Spring'},
#     {   'course': 'COMP 410',
#         'credits': '3.00',
#         'grade': 'B',
#         'name': 'DATA STRUCTURES',
#         'term': '2019 Fall'},
#     {   'course': 'COMP 411',
#         'credits': '4.00',
#         'grade': 'A',
#         'name': 'COMPUTER ORGANIZATN',
#         'term': '2020 Spring'},
#     {   'course': 'COMP 426',
#         'credits': '3.00',
#         'grade': 'A-',
#         'name': 'MODERN WEB PROGRAMMING',
#         'term': '2020 Fall'},
#     {   'course': 'COMP 431',
#         'credits': '3.00',
#         'grade': 'WCV',
#         'name': 'INTERNET SVCS &amp; PROTOCOL',
#         'term': '2021 Spring'},
#     {   'course': 'COMP 455',
#         'credits': '3.00',
#         'grade': 'A',
#         'name': 'MODELS: LANGS/COMPN',
#         'term': '2020 Fall'},
#     {   'course': 'COMP 521',
#         'credits': '3.00',
#         'grade': 'PS',
#         'name': 'FILES AND DATABASES',
#         'term': '2020 Fall'},
#     {   'course': 'COMP 550',
#         'credits': '3.00',
#         'grade': 'PS',
#         'name': 'ALGRTHMS &amp; ANALYSIS',
#         'term': '2020 Fall'},
#     {   'course': 'COMP 590',
#         'credits': '3.00',
#         'grade': 'A-',
#         'name': 'TOPICS COMPUTER SCI',
#         'term': '2021 Spring'},
#     {   'course': 'ECON 101',
#         'credits': '3.00',
#         'grade': 'B+',
#         'name': 'ECON: INTRO',
#         'term': '2019 Summer I'},
#     {   'course': 'EDUC 190',
#         'credits': '2.00',
#         'grade': 'A',
#         'name': 'SPECIAL TOPICS IN EDUCATION',
#         'term': '2018 Fall'},
#     {   'course': 'ENEC 202',
#         'credits': '4.00',
#         'grade': 'BE',
#         'name': 'ENVIRONMENTAL SCIENCE',
#         'term': '2018 Fall'},
#     {   'course': 'ENGL 105',
#         'credits': '3.00',
#         'grade': 'A',
#         'name': 'ENG COMP &amp; RHETORIC',
#         'term': '2018 Fall'},
#     {   'course': 'ENGL 130',
#         'credits': '3.00',
#         'grade': 'A',
#         'name': 'INTRO/FICTION WRIT',
#         'term': '2019 Fall'},
#     {   'course': 'GEOL 101',
#         'credits': '3.00',
#         'grade': 'B',
#         'name': 'PLANET EARTH',
#         'term': '2019 Spring'},
#     {   'course': 'GEOL 101L',
#         'credits': '1.00',
#         'grade': 'A',
#         'name': 'PLANET EARTH LAB',
#         'term': '2019 Spring'},
#     {   'course': 'GSLL 55',
#         'credits': '3.00',
#         'grade': 'B+',
#         'name': 'FYS FANTASIES OF ROME',
#         'term': '2019 Spring'},
#     {   'course': 'HIST ----',
#         'credits': '3.00',
#         'grade': 'BE',
#         'name': 'HIST GENERAL ELECTIVE',
#         'term': '2018 Fall'},
#     {   'course': 'HIST 140',
#         'credits': '3.00',
#         'grade': 'A-',
#         'name': 'THE WORLD SINCE 1945',
#         'term': '2019 Fall'},
#     {   'course': 'LFIT 129',
#         'credits': '1.00',
#         'grade': 'B',
#         'name': 'LIFETIME FITNESS: SKIING',
#         'term': '2018 Fall'},
#     {   'course': 'MATH 110P',
#         'credits': '0.00',
#         'grade': 'BE',
#         'name': 'ALGEBRA',
#         'term': '2018 Fall'},
#     {   'course': 'MATH 129P',
#         'credits': '0.00',
#         'grade': 'BE',
#         'name': 'PRECALCULUS MATHEMATICS',
#         'term': '2018 Fall'},
#     {   'course': 'MATH 231',
#         'credits': '4.00',
#         'grade': 'BE',
#         'name': 'CALC FUNC ONE VAR I',
#         'term': '2018 Fall'},
#     {   'course': 'MATH 232',
#         'credits': '4.00',
#         'grade': 'W',
#         'name': 'CAL FUNC ONE VAR II',
#         'term': '2018 Fall'},
#     {   'course': 'MATH 232',
#         'credits': '4.00',
#         'grade': 'BE',
#         'name': 'CAL FUNC ONE VAR II',
#         'term': '2018 Fall'},
#     {   'course': 'MATH 233',
#         'credits': '4.00',
#         'grade': 'A',
#         'name': 'MULTI VARI CALC I',
#         'term': '2020 Spring'},
#     {   'course': 'MATH 547',
#         'credits': '3.00',
#         'grade': 'B-',
#         'name': 'LINEAR ALGEBRA FOR APPL',
#         'term': '2020 Summer I'},
#     {   'course': 'MUSC 145',
#         'credits': '3.00',
#         'grade': 'B',
#         'name': 'INTRO TO JAZZ',
#         'term': '2018 Fall'},
#     {   'course': 'PHYS 118',
#         'credits': '4.00',
#         'grade': 'PS',
#         'name': 'MECHANICS AND RELATIVITY',
#         'term': '2020 Spring'},
#     {   'course': 'PSYC 101',
#         'credits': '3.00',
#         'grade': 'BE',
#         'name': 'GENERAL PSYCHOLOGY',
#         'term': '2018 Fall'},
#     {   'course': 'RELI 104',
#         'credits': '3.00',
#         'grade': 'B',
#         'name': 'INTRO TO THE NEW TESTAMENT',
#         'term': '2020 Summer I'},
#     {   'course': 'SPAN 203',
#         'credits': '0.00',
#         'grade': 'PL',
#         'name': 'INTERMEDIATE SPANISH I',
#         'term': '2018 Fall'},
#     {   'course': 'STOR 151',
#         'credits': '3.00',
#         'grade': 'BE',
#         'name': 'INTRO TO DATA ANALYSIS',
#         'term': '2018 Fall'},
#     {   'course': 'STOR 155',
#         'credits': '3.00',
#         'grade': 'B+',
#         'name': 'INTRO DATA MODELS &amp; INFERENCE',
#         'term': '2019 Summer I'},
#     {   'course': 'STOR 320',
#         'credits': '4.00',
#         'grade': 'A',
#         'name': 'DATA SCIENCE',
#         'term': '2021 Spring'},
#     {   'course': 'STOR 535',
#         'credits': '3.00',
#         'grade': 'PS',
#         'name': 'PROBABILITY FOR DATA SCIENCE',
#         'term': '2021 Spring'}]
